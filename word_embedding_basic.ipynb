# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# %%
import argparse
import collections
import hashlib
import math
import os
import random
import sys
from tempfile import gettempdir
import zipfile

# %%
import numpy as np
from six.moves import urllib
from six.moves import xrange
import tensorflow as tf

# %%
from tensorflow.contrib.tensorboard.plugins import projector

# %%
data_index = 0

# %%
def _hash_file(fpath):
  hasher = hashlib.sha256()
  with open(fpath, 'rb') as fpath_file:
    for chunk in iter(lambda: fpath_file.read(65535), b''):
      hasher.update(chunk)
  return hasher.hexdigest()

# %%
def word2vec_basic(log_dir):
  """Example of building, training and visualizing a word2vec model."""
  # Create the directory for TensorBoard variables if there is not.
  if not os.path.exists(log_dir):
    os.makedirs(log_dir)

  # Step 1: Download the data.
  # Note: Source website does not support HTTPS right now.
 # url = 'http://mattmahoney.net/dc/'
    url = 'http://mattmahoney.net/dc/dce.html/'

  # pylint: disable=redefined-outer-name
  def maybe_download(filename, expected_bytes, sha256=None):
    """Download a file if not present, and make sure it's the right size."""
    local_filename = os.path.join(gettempdir(), filename)
    if not os.path.exists(local_filename):
      local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                     local_filename)
    statinfo = os.stat(local_filename)

    if sha256 and _hash_file(local_filename) != sha256:
      raise Exception('Failed to verify ' + local_filename + ' due to hash '
                      'mismatch. Can you get to it with a browser?')

    if statinfo.st_size == expected_bytes:
      print('Found and verified', filename)
    else:
      print(statinfo.st_size)
      raise Exception('Failed to verify ' + local_filename +
                      '. Can you get to it with a browser?')
    return local_filename

  filename = maybe_download(
      'text8.zip',
      31344016,
      sha256='a6640522afe85d1963ad56c05b0ede0a0c000dddc9671758a6cc09b7a38e5232')

  # Read the data into a list of strings.
  def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words."""
    with zipfile.ZipFile(filename) as f:
      data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

  vocabulary = read_data(filename) #word tokens i think
  print('Data size', len(vocabulary))

  # Step 2: Build the dictionary and replace rare words with UNK token.
  vocabulary_size = 50000

  def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = {}
    for word, _ in count:
      dictionary[word] = len(dictionary)
    data = []
    unk_count = 0
    for word in words:
      index = dictionary.get(word, 0)
      if index == 0:  # dictionary['UNK']
        unk_count += 1
      data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

  # Filling 4 global variables:
  # data - list of codes (integers from 0 to vocabulary_size-1).
  #   This is the original text but words are replaced by their codes
  # count - map of words(strings) to count of occurrences
  # dictionary - map of words(strings) to their codes(integers)
  # reverse_dictionary - maps codes(integers) to words(strings)
  data, count, unused_dictionary, reverse_dictionary = build_dataset(
      vocabulary, vocabulary_size)
  del vocabulary  # Hint to reduce memory.
  print('Most common words (+UNK)', count[:5])
  print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

  # Step 3: Function to generate a training batch for the skip-gram model.
  def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)  # pylint: disable=redefined-builtin
    if data_index + span > len(data):
      data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
      context_words = [w for w in range(span) if w != skip_window]
      words_to_use = random.sample(context_words, num_skips)
      for j, context_word in enumerate(words_to_use):
        batch[i * num_skips + j] = buffer[skip_window]
        labels[i * num_skips + j, 0] = buffer[context_word]
      if data_index == len(data):
        buffer.extend(data[0:span])
        data_index = span
      else:
        buffer.append(data[data_index])
        data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

  batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
  for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
          reverse_dictionary[labels[i, 0]])

  # Step 4: Build and train a skip-gram model.

  batch_size = 128
  embedding_size = 128  # Dimension of the embedding vector.
  skip_window = 1  # How many words to consider left and right.
  num_skips = 2  # How many times to reuse an input to generate a label.
  num_sampled = 64  # Number of negative examples to sample.

  # We pick a random validation set to sample nearest neighbors. Here we limit
  # the validation samples to the words that have a low numeric ID, which by
  # construction are also the most frequent. These 3 variables are used only for
  # displaying model accuracy, they don't affect calculation.
  valid_size = 16  # Random set of words to evaluate similarity on.
  valid_window = 100  # Only pick dev samples in the head of the distribution.
  valid_examples = np.random.choice(valid_window, valid_size, replace=False)

  graph = tf.Graph()

  with graph.as_default():

    # Input data.
    with tf.name_scope('inputs'):
      train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
      train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
      valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
      # Look up embeddings for inputs.
      with tf.name_scope('embeddings'):
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

      # Construct the variables for the NCE loss
      with tf.name_scope('weights'):
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
      with tf.name_scope('biases'):
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    # Explanation of the meaning of NCE loss:
    #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
    with tf.name_scope('loss'):
      loss = tf.reduce_mean(
          tf.nn.nce_loss(
              weights=nce_weights,
              biases=nce_biases,
              labels=train_labels,
              inputs=embed,
              num_sampled=num_sampled,
              num_classes=vocabulary_size))

    # Add the loss value as a scalar to summary.
    tf.summary.scalar('loss', loss)

    # Construct the SGD optimizer using a learning rate of 1.0.
    with tf.name_scope('optimizer'):
      optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all
    # embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                              valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

    # Merge all summaries.
    merged = tf.summary.merge_all()

    # Add variable initializer.
    init = tf.global_variables_initializer()

    # Create a saver.
    saver = tf.train.Saver()

  # Step 5: Begin training.
  num_steps = 100001

  with tf.compat.v1.Session(graph=graph) as session:
    # Open a writer to write summaries.
    writer = tf.summary.FileWriter(log_dir, session.graph)

    # We must initialize all variables before we use them.
    init.run()
    print('Initialized')

    average_loss = 0
    for step in xrange(num_steps):
      batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                  skip_window)
      feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

      # Define metadata variable.
      run_metadata = tf.RunMetadata()

      # We perform one update step by evaluating the optimizer op (including it
      # in the list of returned values for session.run()
      # Also, evaluate the merged op to get all summaries from the returned
      # "summary" variable. Feed metadata variable to session for visualizing
      # the graph in TensorBoard.
      _, summary, loss_val = session.run([optimizer, merged, loss],
                                         feed_dict=feed_dict,
                                         run_metadata=run_metadata)
      average_loss += loss_val

      # Add returned summaries to writer in each step.
      writer.add_summary(summary, step)
      # Add metadata to visualize the graph for the last run.
      if step == (num_steps - 1):
        writer.add_run_metadata(run_metadata, 'step%d' % step)

      if step % 2000 == 0:
        if step > 0:
          average_loss /= 2000
        # The average loss is an estimate of the loss over the last 2000
        # batches.
        print('Average loss at step ', step, ': ', average_loss)
        average_loss = 0

      # Note that this is expensive (~20% slowdown if computed every 500 steps)
      if step % 10000 == 0:
        sim = similarity.eval()
        for i in xrange(valid_size):
          valid_word = reverse_dictionary[valid_examples[i]]
          top_k = 8  # number of nearest neighbors
          nearest = (-sim[i, :]).argsort()[1:top_k + 1]
          log_str = 'Nearest to %s:' % valid_word
          for k in xrange(top_k):
            close_word = reverse_dictionary[nearest[k]]
            log_str = '%s %s,' % (log_str, close_word)
          print(log_str)
    final_embeddings = normalized_embeddings.eval()

    # Write corresponding labels for the embeddings.
    with open(log_dir + '/metadata.tsv', 'w') as f:
      for i in xrange(vocabulary_size):
        f.write(reverse_dictionary[i] + '\n')

    # Save the model for checkpoints.
    saver.save(session, os.path.join(log_dir, 'model.ckpt'))

    # Create a configuration for visualizing embeddings with the labels in
    # TensorBoard.
    config = projector.ProjectorConfig()
    embedding_conf = config.embeddings.add()
    embedding_conf.tensor_name = embeddings.name
    embedding_conf.metadata_path = os.path.join(log_dir, 'metadata.tsv')
    projector.visualize_embeddings(writer, config)

  writer.close()

  # Step 6: Visualize the embeddings.

  # pylint: disable=missing-docstring
  # Function to draw visualization of distance between embeddings.
  def plot_with_labels(low_dim_embs, labels, filename):
    
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
      x, y = low_dim_embs[i, :]
      plt.scatter(x, y)
      plt.annotate(
          label,
          xy=(x, y),
          xytext=(5, 2),
          textcoords='offset points',
          ha='right',
          va='bottom')

    plt.savefig(filename)

  try:
    # pylint: disable=g-import-not-at-top
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt

    tsne = TSNE(
        perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(),
                                                        'tsne.png'))

  except ImportError as ex:
    print('Please install sklearn, matplotlib, and scipy to show embeddings.')
    print(ex)


# All functionality is run after tf.compat.v1.app.run() (b/122547914). This
# could be split up but the methods are laid sequentially with their usage for
# clarity.
def main(unused_argv):
  # Give a folder path as an argument with '--log_dir' to save
  # TensorBoard summaries. Default is a log folder in current directory.
  current_path = os.path.dirname(os.path.realpath(sys.argv[0]))

  parser = argparse.ArgumentParser()
  parser.add_argument(
      '--log_dir',
      type=str,
      default=os.path.join(current_path, 'log'),
      help='The log directory for TensorBoard summaries.')
  flags, unused_flags = parser.parse_known_args()
  word2vec_basic(flags.log_dir)


if __name__ == '__main__':
  tf.app.run()
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# 2153 mount -> 21616 carmel
# 2153 mount -> 7 to
# 21616 carmel -> 4866 cemetery
# 21616 carmel -> 2153 mount
# 4866 cemetery -> 25 on
# 4866 cemetery -> 21616 carmel
# 25 on -> 1 the
# 25 on -> 4866 cemetery
# Initialized
# Average loss at step  0 :  274.7613525390625
# Nearest to can: canons, supers, boeing, heligoland, zadok, owl, infantryman, pistol,
# Nearest to over: conciliar, moderated, prefectural, piston, boys, bitstream, gurevich, madhava,
# Nearest to however: ellefson, homestead, shunning, nonpolar, tachi, bulgarians, gk, secession,
# Nearest to he: catapulted, organizational, bleachers, telegraphy, marked, capuchin, linde, murder,
# Nearest to would: tint, litas, anand, miraculous, vienna, adventurers, indictment, let,
# Nearest to at: servo, incorporates, competences, toolbox, alberts, director, fort, copernicus,
# Nearest to system: roadway, cavities, labarum, cougars, depressions, kyanite, haakon, judo,
# Nearest to which: deceptively, qf, lesotho, neman, ceiling, screws, ockham, unspoken,
# Nearest to been: phd, cycladic, unverified, epa, pulsation, receptor, tacit, runoff,
# Nearest to states: berle, tenniel, dll, numerology, repel, solidifies, ahimelech, anything,
# Nearest to that: brindisi, nite, migration, ill, shawar, rabbani, morehouse, sobel,
# Nearest to all: cola, stated, purify, barada, shooting, receiver, sterile, riflemen,
# Nearest to an: psoe, personas, dale, yitzhak, alene, stills, mycological, conceiving,
# Nearest to seven: academia, designated, nitrates, maclisp, breathes, schelling, rv, blur,
# Nearest to in: mashing, deductions, macpherson, alkaloids, gorman, highlighting, polg, ripped,
# Nearest to more: modeled, reddish, defected, lepton, solferino, sales, pauling, aldiss,
# Average loss at step  2000 :  113.89997699737549
# Average loss at step  4000 :  52.13662453961372
# Average loss at step  6000 :  32.977561090946196
# Average loss at step  8000 :  23.179697485327722
# Average loss at step  10000 :  17.24831281030178
# Nearest to can: canons, cannot, casualties, raise, vastly, parc, boeing, rebellions,
# Nearest to over: boys, moderated, choosing, afb, telecommunications, deterrent, carbohydrates, shirts,
# Nearest to however: nonpolar, arthropod, map, bulgarians, independent, tudor, death, cia,
# Nearest to he: palatal, adventist, maronite, grendel, feces, demonstration, were, wealth,
# Nearest to would: draw, trend, ruble, effective, let, duo, vienna, owe,
# Nearest to at: maronite, in, incorporates, fort, yang, and, of, director,
# Nearest to system: runways, florida, blades, perfection, versions, shuttlecock, UNK, imperial,
# Nearest to which: yin, neman, and, yu, the, swerve, didn, that,
# Nearest to been: receptor, gerhard, crimea, welcomed, third, reno, sqrt, generic,
# Nearest to states: eddington, anything, fly, backwards, gulf, august, le, quinn,
# Nearest to that: and, sim, this, yu, ill, to, workers, compulsory,
# Nearest to all: stated, yang, shooting, torah, thermometer, you, malt, butt,
# Nearest to an: the, stills, genealogical, stitch, council, puritan, administrative, must,
# Nearest to seven: nine, zero, brien, chanter, four, designated, three, one,
# Nearest to in: and, of, to, nine, on, for, maronite, as,
# Nearest to more: modeled, sales, reddish, ballistic, characters, yang, wastes, olympic,
# Average loss at step  12000 :  13.983180571913719
# Average loss at step  14000 :  11.787915061831475
# Average loss at step  16000 :  9.57463850402832
# Average loss at step  18000 :  8.659783269166946
# Average loss at step  20000 :  8.184967969894409
# Nearest to can: cannot, canons, marek, would, will, vastly, rebellions, owl,
# Nearest to over: teau, deterrent, boys, moderated, choosing, UNK, kapoor, shirts,
# Nearest to however: wct, nonpolar, babylon, bulgarians, tudor, cdot, independent, arthropod,
# Nearest to he: it, wct, kapoor, they, also, russell, adventist, maronite,
# Nearest to would: will, may, ursus, trend, tint, draw, could, can,
# Nearest to at: in, maronite, goliath, cricketers, from, during, incorporates, fort,
# Nearest to system: UNK, runways, florida, flash, nobles, ursus, roadway, perfection,
# Nearest to which: that, this, yin, yu, khanna, one, kapoor, and,
# Nearest to been: was, gerhard, receptor, reno, crimea, domenico, feedback, tasteless,
# Nearest to states: eddington, cdot, ursus, ahimelech, dll, anything, gulf, backwards,
# Nearest to that: which, this, ursus, teau, kapoor, desktops, and, wct,
# Nearest to all: prism, stated, some, teau, bootstrapping, khanna, purify, streams,
# Nearest to an: the, stills, genealogical, lactamase, avionics, puritan, gear, rust,
# Nearest to seven: nine, eight, zero, three, one, five, six, four,
# Nearest to in: and, nine, on, from, of, for, kapoor, with,
# Nearest to more: modeled, reddish, sales, ballistic, cricketers, defected, yang, characters,
# Average loss at step  22000 :  7.599271084308624
# Average loss at step  24000 :  6.994777158141136
# Average loss at step  26000 :  6.5309825882911685
# Average loss at step  28000 :  6.422537796378136
# Average loss at step  30000 :  5.920539198577404
# Nearest to can: would, cannot, will, may, could, canons, marek, vastly,
# Nearest to over: teau, deterrent, moderated, choosing, kapoor, state, vickers, piston,
# Nearest to however: wct, babylon, nonpolar, and, bulgarians, tudor, saguinus, cdot,
# Nearest to he: it, they, there, wct, kapoor, she, also, devanagari,
# Nearest to would: will, may, can, could, ursus, adventurers, tint, trend,
# Nearest to at: in, during, from, maronite, goliath, incorporates, cricketers, saguinus,
# Nearest to system: saguinus, runways, ursus, roadway, nobles, florida, backbone, depressions,
# Nearest to which: that, this, vickers, one, yu, it, khanna, kapoor,
# Nearest to been: was, by, gerhard, receptor, reno, feedback, voltaire, domenico,
# Nearest to states: eddington, cdot, cardiomyopathy, ursus, ahimelech, dll, anything, exactly,
# Nearest to that: which, this, ursus, it, desktops, kapoor, teau, yu,
# Nearest to all: prism, some, saguinus, stated, khanna, yang, teau, you,
# Nearest to an: vickers, cebus, personas, the, avionics, waived, ordinarily, genealogical,
# Nearest to seven: eight, nine, four, five, three, six, zero, two,
# Nearest to in: and, from, nine, on, at, kapoor, cardiomyopathy, mitral,
# Nearest to more: modeled, reddish, leontopithecus, defected, characters, sales, cricketers, totally,
# Average loss at step  32000 :  5.5283330332040785
# Average loss at step  34000 :  6.0014854394197465
# Average loss at step  36000 :  5.653902586936951
# Average loss at step  38000 :  5.422251155257225
# Average loss at step  40000 :  5.5753126550912855
# Nearest to can: would, may, will, cannot, could, must, marek, to,
# Nearest to over: teau, deterrent, moderated, choosing, state, kapoor, vickers, telecommunications,
# Nearest to however: that, wct, babylon, conspirators, tudor, nonpolar, above, and,
# Nearest to he: it, they, she, there, wct, also, kapoor, devanagari,
# Nearest to would: will, may, can, could, ursus, adventurers, tint, to,
# Nearest to at: in, during, after, maronite, from, cricketers, incorporates, goliath,
# Nearest to system: thaler, ursus, chd, backbone, nobles, saguinus, florida, UNK,
# Nearest to which: that, this, thaler, but, vickers, one, it, also,
# Nearest to been: by, was, gerhard, be, receptor, were, domenico, renouf,
# Nearest to states: eddington, cdot, cardiomyopathy, ursus, ahimelech, dll, anything, exactly,
# Nearest to that: which, this, ursus, kapoor, yu, however, teau, mitral,
# Nearest to all: some, prism, saguinus, crabs, khanna, these, you, diablo,
# Nearest to an: the, personas, vickers, amulets, cebus, lactamase, enumerable, avionics,
# Nearest to seven: eight, four, nine, five, six, three, zero, two,
# Nearest to in: from, on, and, at, of, kapoor, shun, nine,
# Nearest to more: less, reddish, leontopithecus, modeled, very, cricketers, defected, chd,
# Average loss at step  42000 :  5.346157058358193
# Average loss at step  44000 :  5.445703470796347
# Average loss at step  46000 :  5.482539905071259
# Average loss at step  48000 :  5.279095505714417
# Average loss at step  50000 :  5.3161970224380495
# Nearest to can: would, may, will, could, cannot, must, might, marek,
# Nearest to over: teau, deterrent, state, kapoor, choosing, moderated, vickers, telecommunications,
# Nearest to however: that, wct, babylon, but, fachhochschule, saguinus, kapoor, tudor,
# Nearest to he: it, they, she, there, who, wct, bayreuth, kapoor,
# Nearest to would: will, can, may, could, globemaster, ursus, to, might,
# Nearest to at: in, during, maronite, after, cricketers, devry, fachhochschule, from,
# Nearest to system: thaler, nobles, ursus, backbone, roadway, saguinus, chd, shuttlecock,
# Nearest to which: that, this, it, thaler, vickers, but, also, wct,
# Nearest to been: was, be, by, cycladic, gerhard, were, renouf, receptor,
# Nearest to states: vulpes, eddington, cdot, ursus, cardiomyopathy, ahimelech, dll, records,
# Nearest to that: which, this, however, kapoor, ursus, when, saguinus, mitral,
# Nearest to all: some, prism, saguinus, these, crabs, globemaster, khanna, fachhochschule,
# Nearest to an: the, personas, amulets, lactamase, ordinarily, cebus, avionics, enumerable,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to in: at, from, devry, during, on, kapoor, nine, fachhochschule,
# Nearest to more: less, pontificia, very, leontopithecus, most, reddish, modeled, defected,
# Average loss at step  52000 :  5.205081117987633
# Average loss at step  54000 :  5.170190618753433
# Average loss at step  56000 :  5.1290793220996855
# Average loss at step  58000 :  4.943535385251045
# Average loss at step  60000 :  5.0797190117836
# Nearest to can: may, would, will, could, cannot, must, might, should,
# Nearest to over: teau, deterrent, within, about, shen, choosing, state, kapoor,
# Nearest to however: but, that, stenella, wct, and, babylon, fachhochschule, saguinus,
# Nearest to he: it, she, they, there, who, wct, bayreuth, we,
# Nearest to would: will, may, can, could, globemaster, might, must, ursus,
# Nearest to at: in, during, from, after, on, saguinus, dingo, cricketers,
# Nearest to system: thaler, lagenorhynchus, ursus, nobles, cavities, saguinus, chd, backbone,
# Nearest to which: that, this, and, but, also, thaler, cet, wct,
# Nearest to been: was, be, by, cycladic, were, gerhard, become, renouf,
# Nearest to states: vulpes, eddington, ursus, cdot, cardiomyopathy, ahimelech, dll, chymotrypsin,
# Nearest to that: which, this, however, but, kapoor, diets, amur, ursus,
# Nearest to all: some, prism, these, saguinus, two, globemaster, crabs, khanna,
# Nearest to an: personas, enumerable, amulets, lactamase, cebus, ordinarily, the, vickers,
# Nearest to seven: five, eight, four, six, nine, three, zero, two,
# Nearest to in: and, devry, at, from, nine, constituci, during, kapoor,
# Nearest to more: less, very, most, pontificia, leontopithecus, paleontology, reddish, defected,
# Average loss at step  62000 :  4.976274642705917
# Average loss at step  64000 :  4.83443838429451
# Average loss at step  66000 :  5.01968611896038
# Average loss at step  68000 :  4.930212164282799
# Average loss at step  70000 :  4.916104339718819
# Nearest to can: may, would, will, could, must, cannot, might, should,
# Nearest to over: teau, four, shen, within, about, deterrent, kapoor, choosing,
# Nearest to however: but, that, wct, stenella, babylon, eurocents, and, fachhochschule,
# Nearest to he: it, she, they, there, who, wct, we, bayreuth,
# Nearest to would: will, may, can, could, might, must, globemaster, to,
# Nearest to at: during, in, from, after, on, cricketers, eurocents, saguinus,
# Nearest to system: thaler, nobles, lagenorhynchus, backbone, ursus, cavities, eurocents, shuttlecock,
# Nearest to which: that, this, it, but, also, cet, vickers, kyushu,
# Nearest to been: be, was, by, become, cycladic, were, gerhard, renouf,
# Nearest to states: vulpes, eddington, ursus, cardiomyopathy, cdot, tenniel, records, ahimelech,
# Nearest to that: which, this, however, but, it, kapoor, ursus, when,
# Nearest to all: some, these, prism, many, both, saguinus, several, frames,
# Nearest to an: the, enumerable, lactamase, ordinarily, cebus, personas, amulets, griff,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to in: at, during, from, devry, with, constituci, kapoor, and,
# Nearest to more: less, most, very, pontificia, leontopithecus, paleontology, reddish, defected,
# Average loss at step  72000 :  4.924109117746353
# Average loss at step  74000 :  4.830535384416581
# Average loss at step  76000 :  4.83253083562851
# Average loss at step  78000 :  4.8161385272741315
# Average loss at step  80000 :  4.714161429524422
# Nearest to can: may, would, will, could, must, cannot, might, should,
# Nearest to over: teau, four, about, within, shen, deterrent, kapoor, vickers,
# Nearest to however: but, that, wct, stenella, eurocents, fachhochschule, kapoor, saguinus,
# Nearest to he: it, she, they, who, there, we, wct, groove,
# Nearest to would: will, may, can, could, must, might, globemaster, cannot,
# Nearest to at: during, in, after, on, from, eurocents, cricketers, dingo,
# Nearest to system: thaler, lagenorhynchus, cougars, nobles, backbone, ursus, shuttlecock, cavities,
# Nearest to which: that, this, also, but, it, what, kyushu, cet,
# Nearest to been: be, was, were, become, by, cycladic, renouf, gerhard,
# Nearest to states: vulpes, eddington, ursus, cardiomyopathy, records, rowe, ahimelech, thaler,
# Nearest to that: which, however, this, but, what, when, kapoor, ursus,
# Nearest to all: some, these, many, prism, both, several, saguinus, globemaster,
# Nearest to an: enumerable, lactamase, personas, cebus, the, amulets, avionics, ordinarily,
# Nearest to seven: eight, six, five, four, nine, three, zero, one,
# Nearest to in: during, at, from, devry, cardiomyopathy, on, of, kapoor,
# Nearest to more: less, most, very, pontificia, leontopithecus, paleontology, defected, electrostatic,
# Average loss at step  82000 :  4.602239032268524
# Average loss at step  84000 :  4.729068922281265
# Average loss at step  86000 :  4.703101961374283
# Average loss at step  88000 :  4.733778911709785
# Average loss at step  90000 :  4.684658407688141
# Nearest to can: may, will, would, could, must, cannot, might, should,
# Nearest to over: teau, about, four, within, shen, deterrent, vickers, kapoor,
# Nearest to however: but, that, wct, although, stenella, eurocents, fachhochschule, which,
# Nearest to he: she, it, they, who, there, wct, we, groove,
# Nearest to would: will, can, could, may, must, might, cannot, globemaster,
# Nearest to at: in, during, on, cricketers, after, maronite, eurocents, saguinus,
# Nearest to system: thaler, lagenorhynchus, ursus, nobles, backbone, cougars, shuttlecock, cet,
# Nearest to which: that, this, it, but, also, kyushu, what, cet,
# Nearest to been: be, become, was, were, by, renouf, cycladic, gerhard,
# Nearest to states: vulpes, eddington, ursus, cardiomyopathy, rowe, thaler, records, ahimelech,
# Nearest to that: which, however, this, what, but, when, kapoor, saguinus,
# Nearest to all: some, these, many, prism, both, several, saguinus, globemaster,
# Nearest to an: enumerable, cebus, lactamase, the, amulets, pills, avionics, rust,
# Nearest to seven: eight, six, five, four, nine, three, zero, one,
# Nearest to in: at, during, on, devry, from, kapoor, and, mitral,
# Nearest to more: less, most, very, pontificia, leontopithecus, paleontology, too, defected,
# Average loss at step  92000 :  4.774279893875122
# Average loss at step  94000 :  4.691548259735107
# Average loss at step  96000 :  4.60160662150383
# Average loss at step  98000 :  4.508808494925499
# Average loss at step  100000 :  4.641531487107277
# Nearest to can: may, would, will, could, must, cannot, should, might,
# Nearest to over: teau, about, within, shen, deterrent, gurevich, pontificia, vickers,
# Nearest to however: but, that, although, wct, fachhochschule, kapoor, eurocents, while,
# Nearest to he: she, it, they, there, who, we, wct, groove,
# Nearest to would: will, can, could, may, might, must, cannot, should,
# Nearest to at: during, in, on, after, cricketers, within, from, dingo,
# Nearest to system: thaler, shuttlecock, systems, nobles, lagenorhynchus, backbone, ursus, cet,
# Nearest to which: that, this, also, it, but, what, vickers, cet,
# Nearest to been: be, become, were, was, renouf, by, had, cycladic,
# Nearest to states: vulpes, eddington, ursus, cardiomyopathy, neutronic, rowe, thaler, nations,
# Nearest to that: which, however, this, what, but, when, yeo, kapoor,
# Nearest to all: some, many, these, both, prism, saguinus, several, globemaster,
# Nearest to an: enumerable, lactamase, personas, cebus, amulets, the, avionics, ordinarily,
# Nearest to seven: eight, six, five, four, nine, three, zero, busan,
# Nearest to in: during, at, devry, kapoor, cardiomyopathy, constituci, within, neutronic,
# Nearest to more: less, most, very, pontificia, leontopithecus, paleontology, too, cheque,
